# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from collections import Counter

from sklearn.model_selection import train_test_split

from keras.preprocessing.sequence import pad_sequences
from keras.models import Sequential
from keras.layers import Embedding, LSTM, Dense
from keras.initializers import RandomUniform
from keras.initializers import glorot_uniform

import tensorflow as tf
from sklearn.metrics import roc_auc_score

def roc_auc(y_true, y_pred):
    return tf.py_function(roc_auc_score, (y_true, y_pred), tf.double)
# Out:
# Using TensorFlow backend.

# %%
column_names = ['id', 'tdate', 'tname', 'ttext', 'ttype', 'trep', 'trtw', 'tfav', 'tstcount', 'tfol', 'tfrien', 'listcount']
df_positive = pd.read_csv('data/tweets/positive.csv', delimiter=';', names=column_names, index_col='id')
df_negative = pd.read_csv('data/tweets/negative.csv', delimiter=';', names=column_names, index_col='id')

# %%
df_positive
# Out:
#                          tdate            tname  \
# id
# 408906692374446080  1386325927  pleease_shut_up
# 408906692693221377  1386325927  alinakirpicheva
# 408906695083954177  1386325927        EvgeshaRe
# 408906695356973056  1386325927    ikonnikova_21
# 408906761416867842  1386325943        JumpyAlex
# ...                        ...              ...
# 411368729235054592  1386912922     diminlisenok
# 411368729424187392  1386912922     qilepocagotu
# 411368796537257984  1386912938       DennyChooo
# 411368797447417856  1386912938      bedowabymir
# 411368857035898880  1386912953  Prituljak_Sibir
#
#                                                                 ttext  ttype  \
# id
# 408906692374446080  @first_timee хоть я и школота, но поверь, у на...      1
# 408906692693221377  Да, все-таки он немного похож на него. Но мой ...      1
# 408906695083954177  RT @KatiaCheh: Ну ты идиотка) я испугалась за ...      1
# 408906695356973056  RT @digger2912: "Кто то в углу сидит и погибае...      1
# 408906761416867842  @irina_dyshkant Вот что значит страшилка :D\nН...      1
# ...                                                               ...    ...
# 411368729235054592  Спала в родительском доме, на своей кровати......      1
# 411368729424187392  RT @jebesilofyt: Эх... Мы немного решили сокра...      1
# 411368796537257984  Что происходит со мной, когда в эфире #proacti...      1
# 411368797447417856  "Любимая,я подарю тебе эту звезду..." Имя како...      1
# 411368857035898880  @Ma_che_rie посмотри #непытайтесьпокинутьомск ...      1
#
#                     trep  trtw  tfav  tstcount  tfol  tfrien  listcount
# id
# 408906692374446080     0     0     0      7569    62      61          0
# 408906692693221377     0     0     0     11825    59      31          2
# 408906695083954177     0     1     0      1273    26      27          0
# 408906695356973056     0     1     0      1549    19      17          0
# 408906761416867842     0     0     0       597    16      23          1
# ...                  ...   ...   ...       ...   ...     ...        ...
# 411368729235054592     0     0     0      1497    56      34          2
# 411368729424187392     0     1     0       692   225     210          0
# 411368796537257984     0     0     0      4905   448     193         13
# 411368797447417856     0     0     0       989   254     251          0
# 411368857035898880     0     0     0      1005   221     178          6
#
# [114911 rows x 11 columns]

# %%
df_negative
# Out:
#                          tdate            tname  \
# id
# 408906762813579264  1386325944  dugarchikbellko
# 408906818262687744  1386325957     nugemycejela
# 408906858515398656  1386325966          4post21
# 408906914437685248  1386325980         Poliwake
# 408906914723295232  1386325980       capyvixowe
# ...                        ...              ...
# 425138243257253888  1390195830         Yanch_96
# 425138339503943682  1390195853          tkit_on
# 425138437684215808  1390195876         ckooker1
# 425138490452344832  1390195889       LisaBeroud
# 425138595251625984  1390195914       sukapavlov
#
#                                                                 ttext  ttype  \
# id
# 408906762813579264  на работе был полный пиддес :| и так каждое за...     -1
# 408906818262687744  Коллеги сидят рубятся в Urban terror, а я из-з...     -1
# 408906858515398656  @elina_4post как говорят обещаного три года жд...     -1
# 408906914437685248  Желаю хорошего полёта и удачной посадки,я буду...     -1
# 408906914723295232  Обновил за каким-то лешим surf, теперь не рабо...     -1
# ...                                                               ...    ...
# 425138243257253888  Но не каждый хочет что то исправлять:( http://...     -1
# 425138339503943682  скучаю так :-( только @taaannyaaa вправляет мо...     -1
# 425138437684215808          Вот и в школу, в говно это идти уже надо(     -1
# 425138490452344832  RT @_Them__: @LisaBeroud Тауриэль, не грусти :...     -1
# 425138595251625984  Такси везет меня на работу. Раздумываю приплат...     -1
#
#                     trep  trtw  tfav  tstcount  tfol  tfrien  listcount
# id
# 408906762813579264     0     0     0      8064   111      94          2
# 408906818262687744     0     0     0        26    42      39          0
# 408906858515398656     0     0     0       718    49     249          0
# 408906914437685248     0     0     0     10628   207     200          0
# 408906914723295232     0     0     0        35    17      34          0
# ...                  ...   ...   ...       ...   ...     ...        ...
# 425138243257253888     0     0     0      1138    32      46          0
# 425138339503943682     0     0     0      4822    38      32          0
# 425138437684215808     0     0     1       165    13      16          0
# 425138490452344832     0     1     0      2516   187     265          0
# 425138595251625984     0     0     0      7778   146      66          5
#
# [111923 rows x 11 columns]

# %%
df_positive['ttype'].unique()
# Out:
# array([1])

# %%
df_negative['ttype'].unique()
# Out:
# array([-1])

# %%
usecols = ['ttext', 'ttype']
df = pd.concat((df_positive[usecols], df_negative[usecols])).sample(frac=1, random_state=42).reset_index(drop=True)

# %%
df
# Out:
#                                                     ttext  ttype
# 0       мыс на меня обиделась:(\nя ей даже ничего не с...     -1
# 1               аааааааааааааааааааа,не хочу на работу :(     -1
# 2       У меня какой-то особенный вид ушей! :D, некото...      1
# 3       @simonovkon  он неплохой человек в жизни. Я ра...     -1
# 4       RT @Darina_Lo: Домааааа\nЕхали на такси, пели ...      1
# ...                                                   ...    ...
# 226829  Хочу, чтобы графический планшетик скорее прише...     -1
# 226830  RT @OmenDougnter_: мы с @fluffy_irk @hamsterka...      1
# 226831  дому чуть больше 30 лет а мне приходится втору...     -1
# 226832  @MIKEFUCKINGWAY @_im_killjoy_ даже представить...     -1
# 226833  через 8 дней будет месяц как мы не общаемся.. ...     -1
#
# [226834 rows x 2 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(df['ttext'], df['ttype'], test_size=0.25, shuffle=True, random_state=42, stratify=df['ttype'])

# %%
X_train.str.split(' ').apply(len).describe(percentiles = [0.25, 0.50, 0.75, 0.90])
# Out:
# count    170125.000000
# mean         12.175812
# std           4.871840
# min           1.000000
# 25%           8.000000
# 50%          11.000000
# 75%          15.000000
# 90%          19.000000
# max          90.000000
# Name: ttext, dtype: float64

# %% [markdown]
# _Без предобработки_ 90% твитов содержат 19 и меньше слов.

# %%
max_twords = X_train.str.split(' ').apply(len).max()

# %%
word_counts = Counter(np.concatenate(X_train.str.split(' ').values))

# %%
sum(word_counts.values())
# Out:
# 2071410

# %%
len(word_counts)
# Out:
# 472075

# %%
sum(word_counts.values()) / len(word_counts)
# Out:
# 4.387883281258275

# %%
word_counts.most_common()
# Out:
# [('не', 50415),
#  ('и', 39433),
#  ('в', 39019),
#  ('я', 35436),
#  ('RT', 27923),
#  ('на', 26362),
#  ('что', 19748),
#  ('с', 18712),
#  ('а', 15770),
#  ('', 14265),
#  ('меня', 13775),
#  (':(', 13417),
#  ('у', 13395),
#  ('как', 11809),
#  ('это', 11058),
#  ('мне', 10931),
#  ('так', 10620),
#  ('все', 9704),
#  ('ты', 8683),
#  ('по', 8334),
#  (':)', 8332),
#  ('Я', 7390),
#  ('за', 7299),
#  ('-', 7197),
#  ('но', 7186),
#  ('уже', 6981),
#  ('то', 6844),
#  (':D', 6566),
#  ('же', 6482),
#  ('бы', 5714),
#  ('только', 5579),
#  ('еще', 5442),
#  ('ну', 5255),
#  ('А', 5232),
#  ('к', 4660),
#  ('вот', 4486),
#  ('когда', 4331),
#  ('тебя', 4277),
#  ('очень', 4197),
#  ('от', 4140),
#  ('он', 4082),
#  ('сегодня', 4074),
#  ('из', 3992),
#  ('просто', 3991),
#  ('(', 3775),
#  ('мы', 3717),
#  ('будет', 3701),
#  ('—', 3608),
#  ('хочу', 3563),
#  (',', 3491),
#  ('до', 3412),
#  ('тебе', 3303),
#  ('тоже', 3286),
#  ('И', 3242),
#  ('даже', 3224),
#  ('да', 3186),
#  ('было', 3168),
#  ('день', 3092),
#  ('для', 3088),
#  ('его', 3083),
#  ('там', 3013),
#  ('теперь', 2855),
#  ('если', 2798),
#  ('В', 2754),
#  ('надо', 2750),
#  ('вообще', 2723),
#  ('нас', 2718),
#  ('о', 2640),
#  ('она', 2582),
#  (')', 2547),
#  ('есть', 2536),
#  ('нет', 2530),
#  ('завтра', 2487),
#  ('без', 2418),
#  ('буду', 2414),
#  ('Не', 2410),
#  ('всё', 2379),
#  ('сейчас', 2361),
#  ('могу', 2357),
#  ('Как', 2333),
#  ('У', 2301),
#  ('Ну', 2237),
#  ('со', 2197),
#  ('тут', 2173),
#  ('или', 2166),
#  ('кто', 2104),
#  ('они', 2086),
#  ('раз', 2060),
#  ('про', 2048),
#  ('вы', 1885),
#  ('ничего', 1860),
#  ('больше', 1839),
#  ('Вот', 1763),
#  ('чем', 1737),
#  ('ещё', 1733),
#  ('мой', 1731),
#  ('можно', 1730),
#  ('всегда', 1716),
#  ('2', 1705),
#  ('потом', 1684),
#  ('был', 1679),
#  ('их', 1662),
#  ('люблю', 1630),
#  ('почему', 1623),
#  ('такой', 1609),
#  (';)', 1604),
#  ('этот', 1581),
#  ('Сегодня', 1574),
#  ('может', 1549),
#  ('С', 1548),
#  ('ни', 1532),
#  (':-)', 1527),
#  ('((', 1494),
#  ('Это', 1490),
#  ('Но', 1477),
#  ('чтобы', 1470),
#  ('время', 1456),
#  ('после', 1454),
#  ('себя', 1434),
#  ('))', 1391),
#  ('быть', 1389),
#  ('Мне', 1374),
#  ('(((', 1367),
#  (')))', 1341),
#  ('была', 1339),
#  ('опять', 1336),
#  ('знаю', 1305),
#  ('всех', 1300),
#  ('На', 1294),
#  ('много', 1259),
#  ('под', 1255),
#  ('3', 1250),
#  ('где', 1249),
#  ('хоть', 1238),
#  ('этого', 1224),
#  ('дома', 1223),
#  ('такие', 1215),
#  ('вас', 1215),
#  ('новый', 1210),
#  ('себе', 1209),
#  ('моя', 1195),
#  ('такая', 1181),
#  ('пока', 1179),
#  ('ее', 1174),
#  ('один', 1173),
#  ('всем', 1162),
#  ('всего', 1136),
#  (':-(', 1122),
#  ('Все', 1122),
#  ('что-то', 1115),
#  ('через', 1114),
#  ('этом', 1109),
#  ('год', 1107),
#  (';(', 1096),
#  ('совсем', 1094),
#  ('во', 1092),
#  ('такое', 1080),
#  ('хочется', 1077),
#  ('/', 1050),
#  ('делать', 1038),
#  ('спать', 1037),
#  ('Так', 1030),
#  ('нужно', 1023),
#  ('нам', 1018),
#  ('мои', 996),
#  ('него', 993),
#  ('лучше', 967),
#  ('никто', 965),
#  ('равно', 954),
#  ('спасибо', 943),
#  ('весь', 937),
#  ('ли', 929),
#  ('вам', 924),
#  ('НЕ', 924),
#  ('ведь', 917),
#  ('скоро', 909),
#  ('вчера', 906),
#  ('никогда', 900),
#  ('5', 896),
#  ('из-за', 894),
#  ('хорошо', 893),
#  ('моей', 884),
#  (':((', 873),
#  ('4', 867),
#  ('потому', 864),
#  ('ж', 863),
#  ('Если', 859),
#  ('чего', 859),
#  ('эти', 856),
#  ('Что', 847),
#  ('=(', 834),
#  ('да,', 833),
#  ('=)', 830),
#  ('дня', 817),
#  ('блин', 808),
#  ('Хочу', 802),
#  ('мама', 800),
#  ('какой', 786),
#  ('снова', 784),
#  ('Только', 774),
#  ('вроде', 773),
#  ('тогда', 771),
#  ('Да', 770),
#  ('уж', 756),
#  ('кого', 752),
#  ('ему', 750),
#  ('два', 750),
#  ('Завтра', 748),
#  ('этой', 744),
#  ('Ты', 743),
#  ('почти', 743),
#  ('сразу', 734),
#  ('них', 726),
#  ('одна', 726),
#  ('настроение', 725),
#  ('утра', 709),
#  ('10', 708),
#  ('о_О', 708),
#  ('Теперь', 707),
#  ('эту', 701),
#  ('часа', 696),
#  ('люди', 694),
#  ('который', 694),
#  ('хотя', 692),
#  ('мной', 691),
#  ('всю', 687),
#  ('смотреть', 681),
#  ('то,', 678),
#  ('домой', 665),
#  ('нет,', 662),
#  ('давно', 660),
#  (':*', 656),
#  ('свой', 656),
#  ('перед', 648),
#  ('жизнь', 646),
#  ('.', 642),
#  ('плохо', 638),
#  ('были', 636),
#  ('тобой', 632),
#  ('точно', 631),
#  ('жизни', 626),
#  ('столько', 625),
#  ('каждый', 625),
#  ('свою', 624),
#  ('Новый', 623),
#  ('идти', 622),
#  ('сама', 622),
#  ('сижу', 621),
#  ('Когда', 620),
#  ('хотела', 619),
#  ('Мы', 618),
#  ('сильно', 617),
#  (':3', 616),
#  ('знаю,', 611),
#  ('будут', 610),
#  ('Спасибо', 600),
#  (':))', 596),
#  ('как-то', 595),
#  ('того', 594),
#  ('первый', 594),
#  ('сделать', 587),
#  ('сколько', 586),
#  ('её', 585),
#  ('об', 585),
#  ('ей', 585),
#  ('которые', 584),
#  ('года', 582),
#  ('Почему', 581),
#  ('эта', 580),
#  ('самый', 576),
#  ('конечно', 571),
#  ('прям', 567),
#  ('лет', 567),
#  ('1', 567),
#  ('при', 562),
#  ('улице', 562),
#  ('школу', 561),
#  ('Очень', 558),
#  ('пойду', 556),
#  ('@', 554),
#  ('чуть', 550),
#  ('сам', 544),
#  ('Кто', 543),
#  ('человек', 539),
#  ('че', 538),
#  ('щас', 536),
#  ('хочет', 535),
#  ('тот', 535),
#  ('нравится', 533),
#  ('самое', 530),
#  ('немного', 525),
#  ('чтоб', 524),
#  ('ней', 523),
#  ('?', 522),
#  ('ночь', 518),
#  ('куда', 516),
#  ('мало', 515),
#  ('таки', 513),
#  (':', 513),
#  ('будем', 511),
#  ('такого', 510),
#  (':|', 507),
#  ('слишком', 507),
#  ('зачем', 506),
#  ('кто-то', 504),
#  ('своей', 500),
#  ('фильм', 500),
#  ('х)', 499),
#  ('та', 497),
#  ('три', 496),
#  ('болит', 494),
#  ('с:', 493),
#  (':(((', 493),
#  ('времени', 493),
#  ('раньше', 492),
#  ('!', 491),
#  ('ко', 490),
#  ('друг', 490),
#  ('минут', 489),
#  ('Надо', 489),
#  ('долго', 489),
#  ('блин,', 487),
#  ('оно', 487),
#  ('ибо', 486),
#  ('нельзя', 484),
#  ('скучаю', 484),
#  ('думаю', 482),
#  ('второй', 480),
#  ('писать', 474),
#  ('им', 472),
#  ('одной', 471),
#  ('правда', 469),
#  ('утро', 466),
#  ('пор', 465),
#  ('свои', 465),
#  ('кем', 462),
#  ('кому', 459),
#  ('6', 458),
#  ('моего', 454),
#  ('посмотреть', 454),
#  ('ним', 452),
#  ('сих', 451),
#  ('последний', 450),
#  ('людей', 449),
#  ('...', 449),
#  ('#RT', 448),
#  ('лишь', 448),
#  ('именно', 448),
#  ('Он', 446),
#  ('Всем', 443),
#  (':DD', 440),
#  ('какая', 440),
#  ('Вы', 440),
#  ('значит', 440),
#  ('пару', 437),
#  ('этим', 431),
#  ('тем', 430),
#  ('б', 430),
#  ('того,', 430),
#  ('быстро', 428),
#  ('нее', 428),
#  ('так,', 422),
#  ('Доброе', 421),
#  ('кажется', 420),
#  ('Уже', 420),
#  ('вечер', 419),
#  ('Меня', 417),
#  ('8', 413),
#  ('понимаю', 412),
#  ('^_^', 411),
#  ('настроения', 411),
#  ('школе', 410),
#  (':)))', 407),
#  ('часов', 406),
#  ('мою', 406),
#  ('7', 404),
#  ('смотрю', 404),
#  ('самом', 402),
#  ('году', 400),
#  ('фото', 399),
#  ('найти', 399),
#  ('Даже', 398),
#  ('Еще', 395),
#  ('над', 394),
#  ('реально', 394),
#  ('твой', 393),
#  ('иногда', 391),
#  ('жду', 388),
#  ('неделю', 388),
#  ('будто', 386),
#  ('целый', 385),
#  ('никак', 385),
#  ('наверное', 383),
#  ('стоит', 382),
#  ('таких', 379),
#  ('думала', 379),
#  ('жаль', 379),
#  ('видео', 376),
#  ('жить', 375),
#  ('нг', 373),
#  ('вк', 373),
#  ('пол', 371),
#  ('сказала', 371),
#  ('туда', 369),
#  ('телефон', 368),
#  ('своих', 368),
#  ('какие', 367),
#  ('ахах', 367),
#  ('нормально', 365),
#  ('днем', 364),
#  ('9', 364),
#  ('мое', 363),
#  ('зато', 362),
#  ('ночи', 362),
#  ('одного', 362),
#  ('пришла', 362),
#  ('осталось', 362),
#  ('поэтому', 361),
#  ('По', 361),
#  ('моих', 359),
#  ('За', 358),
#  ('вместе', 357),
#  ('час', 355),
#  ('две', 354),
#  ('О', 353),
#  ('такую', 353),
#  ('хотел', 353),
#  ('более', 351),
#  ('НГ', 351),
#  ('вся', 351),
#  ('#євромайдан', 349),
#  ('какой-то', 348),
#  ('Сейчас', 348),
#  ('давай', 347),
#  ('хорошо,', 347),
#  ('ужасно', 346),
#  ('((((', 346),
#  ('Просто', 346),
#  ('здесь', 345),
#  ('%)', 344),
#  ('надеюсь', 343),
#  ('том', 341),
#  ('круто', 338),
#  ('снег', 336),
#  ('сидеть', 335),
#  ('Блин,', 332),
#  ('жалко', 332),
#  ('недели', 331),
#  ('Мой', 330),
#  ('аж', 329),
#  ('ахаха', 328),
#  ('Моя', 327),
#  ('походу', 327),
#  ('"', 326),
#  ('работу', 325),
#  ('утром', 325),
#  ('кроме', 325),
#  ('пусть', 324),
#  ('назад', 323),
#  ('хватает', 322),
#  ('уроки', 321),
#  ('твит', 321),
#  ('кажется,', 320),
#  ('бля', 319),
#  ('самая', 318),
#  ('20', 318),
#  ('Вчера', 317),
#  ('рядом', 317),
#  ('вместо', 317),
#  ('другой', 317),
#  ('будешь', 316),
#  ('читать', 315),
#  ('приятно', 315),
#  ('помню', 315),
#  ('несколько', 314),
#  ('голова', 314),
#  ('ехать', 313),
#  ('придется', 313),
#  ('чувствую', 311),
#  ('нибудь', 311),
#  ('рано', 310),
#  ('любимый', 309),
#  ('типа', 307),
#  ('знает', 306),
#  ('стало', 306),
#  ('сказать', 306),
#  ('Люблю', 305),
#  ('дней', 305),
#  ('скорее', 305),
#  ('ТЫ', 305),
#  ('пошла', 304),
#  ('День', 304),
#  ('нет(', 303),
#  ('своего', 302),
#  ('ждать', 302),
#  ('боюсь', 300),
#  ('главное', 300),
#  (':-D', 300),
#  ('сказал', 299),
#  ('пиздец', 299),
#  ('должна', 299),
#  ('обычно', 298),
#  ('меня,', 298),
#  ('купить', 298),
#  ('твиттер', 297),
#  ('ненавижу', 297),
#  ('самого', 297),
#  ('человека', 297),
#  ('еду', 295),
#  ('одно', 295),
#  ('ходить', 295),
#  ('написать', 293),
#  ('Блин', 293),
#  ('))))', 292),
#  ('особенно', 292),
#  ('НА', 292),
#  ('лень', 292),
#  ('ЧТО', 290),
#  ('хочешь', 289),
#  ('этих', 289),
#  ('дальше', 288),
#  ('Опять', 288),
#  ('забыла', 287),
#  ('МЕНЯ', 287),
#  (':-/', 286),
#  ('наш', 284),
#  ('30', 283),
#  ('нет.', 283),
#  ('сделала', 283),
#  ('блять', 283),
#  ('начала', 283),
#  ('деньги', 282),
#  ('говорит', 282),
#  ('что,', 281),
#  ('нового', 281),
#  ('хороший', 281),
#  ('нашла', 279),
#  ('работе', 279),
#  ('те', 279),
#  ('15', 279),
#  ('норм', 278),
#  ('таким', 278),
#  ('пора', 276),
#  ('твои', 275),
#  ('могла', 275),
#  ('скучно', 275),
#  ('все,', 274),
#  ('конечно,', 274),
#  ('Она', 273),
#  ('день,', 272),
#  ('Сижу', 272),
#  ('том,', 272),
#  ('одну', 271),
#  ('смогу', 271),
#  ('До', 271),
#  ('фотки', 270),
#  ('постоянно', 269),
#  ('Мама', 269),
#  ('своим', 268),
#  ('часто', 268),
#  ('идет', 267),
#  ('После', 266),
#  ('кстати', 266),
#  ('нашей', 266),
#  ('вижу', 264),
#  ('ночью', 262),
#  ('знаешь', 262),
#  ('месяц', 262),
#  ('либо', 262),
#  ('денег', 261),
#  ('Скоро', 261),
#  ('можешь', 261),
#  ('наши', 261),
#  ('Всё', 259),
#  ('видела', 258),
#  ('хочу,', 258),
#  ('иду', 258),
#  ('работает', 257),
#  ('снега', 257),
#  ('раза', 257),
#  ('момент', 256),
#  ('работать', 256),
#  ('я,', 255),
#  ('пойти', 254),
#  ('купила', 254),
#  ('вдруг', 254),
#  ('нужен', 254),
#  ('последнее', 254),
#  ('место', 254),
#  ('нечего', 253),
#  ('12', 252),
#  ('самые', 252),
#  ('–', 251),
#  ('настолько', 251),
#  ('папа', 250),
#  ('чо', 249),
#  ('рождения', 249),
#  ('нету', 249),
#  ('^^', 249),
#  ('Какой', 249),
#  ('моим', 248),
#  ('работы', 247),
#  ('должен', 245),
#  ('стал', 244),
#  ('Пока', 244),
#  ('решила', 244),
#  ('говорят', 243),
#  ('руки', 242),
#  ('выходные', 242),
#  ('наконец', 242),
#  ('гулять', 241),
#  ('К', 241),
#  ('меньше', 241),
#  ('глаза', 240),
#  ('любит', 240),
#  ('подарок', 240),
#  ('тви', 239),
#  ('могут', 239),
#  ('привет', 237),
#  ('Да,', 235),
#  ('интересно', 235),
#  ('вечером', 234),
#  (':с', 233),
#  ('деле', 232),
#  ('сначала', 231),
#  ('этому', 230),
#  ('написала', 229),
#  ('То', 229),
#  (':DDD', 228),
#  ('друзья', 227),
#  ('ради', 227),
#  ('11', 227),
#  ('МНЕ', 227),
#  ('между', 226),
#  ('Q:', 226),
#  ('A:', 226),
#  ('думаю,', 226),
#  ('России', 226),
#  ('хорошего', 226),
#  ('действительно', 226),
#  ('которая', 225),
#  ('учить', 225),
#  ('ну,', 225),
#  ('спать,', 224),
#  ('Что-то', 223),
#  ('КАК', 223),
#  ('песни', 223),
#  ('бывает', 222),
#  ('думал', 222),
#  ('наверно', 222),
#  ('..', 221),
#  ('говорить', 221),
#  ('ахахах', 221),
#  ('л', 220),
#  ('жаль,', 220),
#  ('вставать', 220),
#  ('дело', 220),
#  ('поняла', 220),
#  ('пишу', 220),
#  ('вот,', 219),
#  ('играть', 219),
#  ('собой', 219),
#  ('чувство,', 219),
#  ('обязательно', 219),
#  ('понедельник', 219),
#  ('новогоднего', 218),
#  ('доброе', 217),
#  ('прямо', 217),
#  ('ваще', 217),
#  ('стала', 217),
#  ('@TukvaSociopat:', 216),
#  ('ладно,', 215),
#  ('против', 215),
#  ('спасибо,', 215),
#  ('одни', 214),
#  ('рада', 213),
#  ('голове', 213),
#  ('думала,', 212),
#  ('есть,', 212),
#  ('ладно', 212),
#  ('Хотя', 212),
#  ('хд', 212),
#  ('Может', 212),
#  ('Есть', 211),
#  ('понимаю,', 211),
#  ('Они', 211),
#  ('желание', 210),
#  ('недавно', 210),
#  ('ними', 209),
#  ('неё', 209),
#  ('чай', 209),
#  ('любовь', 208),
#  ('каникулы', 208),
#  ('вокруг', 208),
#  ('кстати,', 207),
#  ('тебя,', 207),
#  ('парень', 206),
#  ('Или', 206),
#  ('видел', 206),
#  ('слова', 205),
#  (';-)', 205),
#  ('не,', 205),
#  ('чувство', 205),
#  ('ноги', 204),
#  ('часть', 204),
#  ('же,', 204),
#  ('серия', 204),
#  ('ЭТО', 203),
#  ('правильно', 203),
#  ('любимая', 202),
#  ('двух', 202),
#  ('устала', 200),
#  ('успела', 200),
#  ('мне,', 200),
#  ('никого', 200),
#  ('страшно', 199),
#  ('хотелось', 199),
#  ('дела', 199),
#  ('никуда', 199),
#  ('грустно', 198),
#  ('нь', 198),
#  ('получается', 198),
#  ('кого-то', 198),
#  ('последние', 197),
#  ('сезон', 197),
#  ('концерт', 197),
#  ('вопрос', 197),
#  ('мир', 196),
#  ('родители', 196),
#  ('погода', 196),
#  ('голову', 195),
#  ('нужна', 195),
#  ('вообще,', 195),
#  ('наконец-то', 195),
#  ('сделал', 195),
#  ('сука', 195),
#  ('никому', 195),
#  ('музыку', 194),
#  ('видимо', 194),
#  ('везде', 194),
#  ('моем', 194),
#  ('брат', 194),
#  ('мог', 193),
#  ('своими', 192),
#  ('твоя', 192),
#  ('НУ', 191),
#  ('субботу', 190),
#  ('оч', 190),
#  ('забыл', 189),
#  ('…', 189),
#  ('кино', 189),
#  ('обратно', 189),
#  ('хуже', 188),
#  ('увидела', 188),
#  ('хорошая', 188),
#  ('новые', 188),
#  ('&lt;3', 188),
#  ('всей', 188),
#  ('итоге', 188),
#  ('весело', 187),
#  (':((((', 187),
#  ('все-таки', 187),
#  ('кофе', 187),
#  ('похоже', 187),
#  ('которых', 187),
#  ('обидно', 187),
#  ('!!!', 187),
#  ('самой', 186),
#  ('конце', 186),
#  ('взять', 185),
#  ('друга', 184),
#  ('около', 184),
#  ('одном', 183),
#  ('мысли', 183),
#  ('вечера', 183),
#  ('Нет', 183),
#  ('начал', 183),
#  ('пятницу', 183),
#  ('ой', 183),
#  ('Днем', 182),
#  ('безумно', 182),
#  ('моему', 181),
#  ('увидеть', 181),
#  ('холодно', 181),
#  ('иди', 181),
#  ('пить', 181),
#  ('песню', 180),
#  ('лучший', 180),
#  ('смотрела', 180),
#  ('почему-то', 180),
#  ('слушать', 180),
#  ('слово', 179),
#  ('делаю', 178),
#  ('где-то', 178),
#  ('конец', 178),
#  (',что', 178),
#  ('друзей', 178),
#  ('больно', 178),
#  ('оказывается', 178),
#  ('экзамен', 177),
#  ('решил', 177),
#  ('сердце', 176),
#  ('Зачем', 176),
#  ('ТАК', 176),
#  ('должны', 176),
#  ('последняя', 175),
#  ('крутой', 175),
#  ('тебе,', 175),
#  ('далеко', 175),
#  ('Где', 175),
#  ('13', 175),
#  ('сами', 175),
#  ('было,', 174),
#  ('слушаю', 174),
#  ('сказала,', 174),
#  ('спокойной', 173),
#  ('хватит', 173),
#  ('пишет', 173),
#  ('дни', 172),
#  ('читаю', 172),
#  ('отлично', 172),
#  ('Там', 172),
#  ('посмотрела', 172),
#  ('такими', 172),
#  ('сказали', 171),
#  ('купил', 170),
#  ('тех', 170),
#  ('бля,', 170),
#  ('соскучилась', 170),
#  ('пришлось', 170),
#  ('свое', 170),
#  ('100', 170),
#  ('обожаю', 170),
#  ('школы', 170),
#  ('зима', 169),
#  ('голос', 169),
#  ('первой', 169),
#  ('большой', 169),
#  ('твоей', 169),
#  ('девушки', 169),
#  ('капец', 168),
#  ('короче', 168),
#  ('начинается', 168),
#  ('сходить', 168),
#  ('какое', 168),
#  ('кот', 168),
#  ('прости', 168),
#  ('умею', 168),
#  ('Ну,', 167),
#  ('шк', 167),
#  ('пять', 167),
#  ('Первый', 167),
#  ('ВСЕ', 167),
#  ('Год', 167),
#  ('песня', 167),
#  ('др', 167),
#  ('тож', 166),
#  ('От', 166),
#  ('зря', 166),
#  ('Ненавижу', 165),
#  ('должно', 165),
#  ('сон', 165),
#  ('надеюсь,', 165),
#  ('сложно', 165),
#  ('домой,', 164),
#  ('o_O', 164),
#  ('какая-то', 164),
#  ('Для', 164),
#  ('как?', 164),
#  ('скучать', 164),
#  ('декабря', 164),
#  ('\nЯ', 164),
#  ('(((((', 163),
#  ('поняла,', 163),
#  ('ахах,', 162),
#  ('конца', 162),
#  ('тупо', 161),
#  ('проснулась', 161),
#  ('интернет', 161),
#  ('Буду', 161),
#  ('Хоть', 161),
#  ('неделя', 161),
#  ('@CIO_Optimal', 160),
#  ('какого', 160),
#  ('следующий', 160),
#  ('нем', 160),
#  ('пары', 160),
#  ('новую', 159),
#  ('будет,', 159),
#  ('любимого', 159),
#  ('вечно', 159),
#  ('смешно', 158),
#  ('ты?', 158),
#  ('счастья', 157),
#  ('которого', 157),
#  ('дома,', 157),
#  ('понял', 156),
#  ('пишут', 156),
#  ('класс', 156),
#  ('твиттере', 156),
#  ('серии', 156),
#  ('письмо', 155),
#  ('будет)', 155),
#  ('сидит', 155),
#  ('урок', 155),
#  ('которой', 155),
#  ('ты,', 155),
#  ('номер', 154),
#  ('наших', 154),
#  ('девушка', 154),
#  (',а', 154),
#  ('подарки', 154),
#  ('Через', 154),
#  ('да.', 154),
#  ('подруга', 154),
#  ('Чем', 153),
#  ('планы', 153),
#  ('хорошее', 153),
#  ('мамой', 153),
#  ('тому', 153),
#  ('истории', 153),
#  ('видеть', 153),
#  ('любишь', 153),
#  ('что-нибудь', 153),
#  ('разу', 152),
#  ('ума', 152),
#  ('сюда', 152),
#  ('городе', 152),
#  ('начало', 152),
#  ('классно', 152),
#  ('Мои', 152),
#  ('боль', 152),
#  ('утро,', 151),
#  ('пожалуйста', 151),
#  ('начинаю', 151),
#  ('куча', 150),
#  ('волосы', 150),
#  ('плакать', 150),
#  ('Зато', 150),
#  ('хорошие', 150),
#  ('хотят', 150),
#  ('особо', 149),
#  ('отличный', 149),
#  ('+', 149),
#  ('начать', 148),
#  ('других', 148),
#  ('делает', 148),
#  ('дали', 148),
#  ('месяца', 148),
#  ('метро', 148),
#  ('Вам', 148),
#  ('проблемы', 148),
#  ('наверное,', 148),
#  ('любить', 147),
#  ('станет', 147),
#  ('Москве', 147),
#  ('любимые', 147),
#  ('год,', 147),
#  ('кучу', 146),
#  ('пришел', 146),
#  ('спокойно', 146),
#  ('людей,', 146),
#  ('нашего', 146),
#  ('пошел', 146),
#  ('шо', 146),
#  ('летом', 146),
#  ('Ни', 146),
#  ('получилось', 145),
#  ('удачи', 145),
#  ('40', 145),
#  ('любимой', 145),
#  ('обо', 145),
#  ('Иногда', 145),
#  ('лицо', 144),
#  ('і', 144),
#  ('наша', 144),
#  ('явно', 144),
#  ('люди,', 144),
#  ('говорю', 143),
#  ('новости', 143),
#  ('Смотрю', 142),
#  ('нашел', 142),
#  ('идиот', 142),
#  ('вспомнила', 142),
#  ('честно', 142),
#  ('первая', 142),
#  ('сериал', 142),
#  ('город', 142),
#  ('играет', 142),
#  ('#ХочуПровестиНовогоднююНочьВместеС', 141),
#  ('плохо,', 141),
#  ('поздно', 141),
#  ('становится', 141),
#  ('третий', 141),
#  ('редко', 141),
#  ('юм', 140),
#  ('моё', 140),
#  ('горло', 140),
#  ('которую', 139),
#  ('Нет,', 139),
#  ...]

# %% [markdown]
# Видно, что чаще всего встречаются стоп-слова. Не будем их обрабатывать сейчас.

# %%
pd.Series(word_counts).describe(percentiles=[0.75, 0.9, 0.95, 0.99])
# Out:
# count    472075.000000
# mean          4.387883
# std         161.054539
# min           1.000000
# 50%           1.000000
# 75%           1.000000
# 90%           3.000000
# 95%           6.000000
# 99%          29.000000
# max       50415.000000
# dtype: float64

# %% [markdown]
# По крайней мере 75% слов встречаются только 1 раз. 90% - 3 и меньше раза. Рассмотрим топ-10% слов.

# %%
max_words = int(len(word_counts) * 0.1)

# %%
def transform(X, word_counts, max_words, max_len):
    X = X.str.split(' ')
    ids = dict((word, min(i, max_words) + 1) for (i, (word, _)) in enumerate(word_counts.most_common()))
    X = X.apply(lambda x: [ids[y] if y in ids else max_words for y in x])
    return pad_sequences(X, truncating='pre', padding='pre', maxlen=max_len)

# %%
X_train_transformed = transform(X_train, word_counts, max_words, max_twords)

# %%
embedding_dim = 32
model = Sequential([
    Embedding(max_words + 2, embedding_dim, mask_zero=True, embeddings_initializer=RandomUniform(-0.01, 0.01, seed=42)),
    LSTM(128, kernel_initializer=glorot_uniform(seed=42), dropout=0.1, recurrent_dropout=0.1),
    Dense(1, activation='tanh')
])

# %%
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=[roc_auc])

# %%
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_3 (Embedding)      (None, None, 32)          1510688
# _________________________________________________________________
# lstm_3 (LSTM)                (None, 128)               82432
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 129
# =================================================================
# Total params: 1,593,249
# Trainable params: 1,593,249
# Non-trainable params: 0
# _________________________________________________________________

# %%
batch_size = 2000
max_epochs = 10
model.fit(X_train_transformed, y_train, epochs=max_epochs, batch_size=batch_size, shuffle=True, verbose=1)
# Out:
# /home/nikolai/Projects/MIPT-ML-Fall-2019/env/lib/python3.7/site-packages/tensorflow_core/python/framework/indexed_slices.py:424: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# Epoch 1/10
# 170125/170125 [==============================] - 204s 1ms/step - loss: -1.6776 - roc_auc: 0.8060
# Epoch 2/10
# 170125/170125 [==============================] - 202s 1ms/step - loss: -3.5141 - roc_auc: 0.9051
# Epoch 3/10
# 170125/170125 [==============================] - 201s 1ms/step - loss: -4.5223 - roc_auc: 0.9242
# Epoch 4/10
# 170125/170125 [==============================] - 201s 1ms/step - loss: -4.5290 - roc_auc: 0.9277
# Epoch 5/10
# 170125/170125 [==============================] - 201s 1ms/step - loss: -4.8458 - roc_auc: 0.9292
# Epoch 6/10
# 170125/170125 [==============================] - 201s 1ms/step - loss: -5.0034 - roc_auc: 0.9375
# Epoch 7/10
# 170125/170125 [==============================] - 201s 1ms/step - loss: -4.7172 - roc_auc: 0.9447
# Epoch 8/10
# 170125/170125 [==============================] - 200s 1ms/step - loss: -5.2685 - roc_auc: 0.9467
# Epoch 9/10
# 170125/170125 [==============================] - 201s 1ms/step - loss: -4.6488 - roc_auc: 0.9370
# Epoch 10/10
# 170125/170125 [==============================] - 200s 1ms/step - loss: -4.8010 - roc_auc: 0.9198

# %%
X_test_transformed = transform(X_test, word_counts, max_words, max_twords)

# %%
model.evaluate(X_test_transformed, y_test)
# Out:
# 56709/56709 [==============================] - 39s 691us/step
# [-3.6233027854780584, 0.8405951261520386]

# %% [markdown]
# Предобработка текста:

# %%
from pymystem3 import Mystem
stemmer = Mystem()

import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
stop_words = set(stopwords.words('russian') + stopwords.words('english'))

import re
space_characters = re.compile(r"[\s_]+")
email = re.compile(r"\w+([-+.']\w+)*@\w+([-.]\w+)*\.\w+([-.]\w+)*")
url = re.compile(r"http[s]?:\/\/(?:[a-zA-Z]|[0-9]|[$-_@.&+]|[!*\(\),]|(?:%[0-9a-fA-F][0-9a-fA-F]))+")
username = re.compile(r"@[\w_]+")
allowed_tokens = re.compile(r"[\w']+|[!?:'(\)@\+\-]")
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/nikolai/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
def process(string):
    string = string.lower()
    string = re.sub(email, 'email', string)
    string = re.sub(url, 'url', string)
    string = re.sub(username, 'username', string)
    string = re.sub(space_characters, ' ', string)
    # Оставим пунктуацию: мы пользуемся нейронной моделью
    # + смайлы вроде :) и :( имеют смысл для текущей задачи
    string = ' '.join(re.findall(allowed_tokens, string))
    string = ''.join(stemmer.lemmatize(string))
    string = string.strip()
    return string

# %%
# %%time
X_train_processed = X_train.apply(process)
X_train_processed = X_train_processed.str.split(' ').apply(lambda x: ' '.join(y for y in x if y not in stop_words))
# Out:
# CPU times: user 24.6 s, sys: 2.22 s, total: 26.8 s
# Wall time: 1min 39s

# %%
X_train_processed.str.split(' ').apply(len).describe(percentiles = [0.25, 0.50, 0.75, 0.90])
# Out:
# count    170125.000000
# mean         10.727877
# std           4.522635
# min           1.000000
# 25%           8.000000
# 50%          10.000000
# 75%          13.000000
# 90%          16.000000
# max         130.000000
# Name: ttext, dtype: float64

# %%
max_twords = X_train.str.split(' ').apply(len).max()

# %%
word_counts = Counter(np.concatenate(X_train_processed.str.split(' ').values))

# %%
sum(word_counts.values())
# Out:
# 1825080

# %%
len(word_counts)
# Out:
# 89395

# %%
sum(word_counts.values()) / len(word_counts)
# Out:
# 20.41590692991778

# %%
word_counts.most_common()
# Out:
# [('(', 159350),
#  (')', 146082),
#  ('username', 111853),
#  (':', 111180),
#  ('!', 50201),
#  ('-', 38541),
#  ('rt', 28645),
#  ('?', 26869),
#  ('url', 25001),
#  ('это', 16128),
#  ('весь', 9088),
#  ('хотеть', 8872),
#  ('день', 8389),
#  ('сегодня', 6633),
#  ('мочь', 6391),
#  ('очень', 5728),
#  ('знать', 5257),
#  ('просто', 5227),
#  ('год', 5042),
#  ('любить', 4568),
#  ('человек', 4512),
#  ('свой', 4221),
#  ('3', 4204),
#  ('завтра', 4017),
#  ('новый', 3911),
#  ('хороший', 3804),
#  ('вообще', 3638),
#  ('самый', 3443),
#  ('делать', 3436),
#  ('спасибо', 3291),
#  ('понимать', 3261),
#  ('спать', 3115),
#  ('блин', 3095),
#  ('сказать', 3087),
#  ('почему', 3074),
#  ('утро', 3042),
#  ('думать', 3028),
#  ('который', 3021),
#  ('смотреть', 3013),
#  ('время', 2999),
#  ('идти', 2840),
#  ('2', 2802),
#  ('говорить', 2793),
#  ('пойти', 2724),
#  ('сидеть', 2599),
#  ('давать', 2592),
#  ('жизнь', 2516),
#  ('писать', 2513),
#  ('друг', 2500),
#  ('сделать', 2476),
#  ('ничто', 2372),
#  ('школа', 2365),
#  ('настроение', 2270),
#  ('скоро', 2231),
#  ('ночь', 2181),
#  ('мама', 2160),
#  ('первый', 2144),
#  ('ждать', 2122),
#  ('час', 2070),
#  ('приходить', 2040),
#  ('болеть', 2027),
#  ('наш', 2012),
#  ('твой', 1969),
#  ('становиться', 1963),
#  ('хотеться', 1905),
#  ('написать', 1889),
#  ('работа', 1854),
#  ('видеть', 1838),
#  ('ахах', 1831),
#  ('посмотреть', 1798),
#  ('находить', 1788),
#  ('начинать', 1766),
#  ('никто', 1751),
#  ('пока', 1738),
#  ('любимый', 1732),
#  ('последний', 1730),
#  ('добрый', 1700),
#  ('забывать', 1677),
#  ('оставаться', 1665),
#  ('вечер', 1642),
#  ('дело', 1611),
#  ('5', 1589),
#  ('купить', 1587),
#  ('неделя', 1554),
#  ('плохо', 1544),
#  ('1', 1513),
#  ('дома', 1501),
#  ('нравиться', 1500),
#  ('каждый', 1499),
#  ('скучать', 1490),
#  ('урок', 1437),
#  ('читать', 1434),
#  ('выходить', 1429),
#  ('вчера', 1423),
#  ('9', 1404),
#  ('снег', 1398),
#  ('4', 1392),
#  ('работать', 1372),
#  ('фильм', 1367),
#  ('нужно', 1364),
#  ('голова', 1359),
#  ('ехать', 1350),
#  ('жить', 1349),
#  ('рано', 1325),
#  ('хотя', 1296),
#  ('ходить', 1256),
#  ('надеяться', 1253),
#  ('нужный', 1252),
#  ('ахи', 1243),
#  ('телефон', 1240),
#  ('домой', 1240),
#  ('получаться', 1239),
#  ('жаль', 1224),
#  ('проходить', 1213),
#  ('дом', 1204),
#  ('сон', 1199),
#  ('нга', 1191),
#  ('приезжать', 1183),
#  ('правда', 1179),
#  ('бля', 1174),
#  ('пара', 1144),
#  ('второй', 1143),
#  ('мало', 1141),
#  ('10', 1134),
#  ('равный', 1119),
#  ('слово', 1112),
#  ('решать', 1111),
#  ('уходить', 1106),
#  ('пора', 1104),
#  ('вставать', 1090),
#  ('х', 1085),
#  ('парень', 1084),
#  ('вроде', 1084),
#  ('песня', 1071),
#  ('рука', 1061),
#  ('точно', 1060),
#  ('улица', 1049),
#  ('твиттер', 1042),
#  ('таки', 1029),
#  ('че', 1024),
#  ('увидеть', 1024),
#  ('приходиться', 1011),
#  ('зима', 1006),
#  ('привет', 1005),
#  ('место', 1004),
#  ('фотка', 1002),
#  ('просыпаться', 995),
#  ('рождение', 994),
#  ('играть', 994),
#  ('большой', 982),
#  ('крутой', 980),
#  ('помнить', 978),
#  ('прощать', 970),
#  ('снова', 967),
#  ('новогодний', 967),
#  ('минута', 960),
#  ('девушка', 956),
#  ('помогать', 940),
#  ('давно', 937),
#  ('круто', 930),
#  ('сразу', 928),
#  ('выходной', 922),
#  ('подарок', 921),
#  ('dd', 919),
#  ('сильно', 910),
#  ('кстати', 904),
#  ('получать', 896),
#  ('заканчиваться', 894),
#  ('успевать', 889),
#  ('глаз', 887),
#  ('узнавать', 884),
#  ('слушать', 883),
#  ('класс', 882),
#  ('прямой', 881),
#  ('плохой', 881),
#  ('любовь', 868),
#  ('взять', 865),
#  ('деньги', 863),
#  ('сдавать', 863),
#  ('бояться', 861),
#  ('начинаться', 861),
#  ('лента', 860),
#  ('чувствовать', 853),
#  ('быстро', 850),
#  ('наверное', 844),
#  ('ненавидеть', 843),
#  ('вопрос', 841),
#  ('ладно', 840),
#  ('оказываться', 838),
#  ('город', 830),
#  ('смочь', 828),
#  ('12', 826),
#  ('8', 825),
#  ('ребенок', 822),
#  ('милый', 821),
#  ('должный', 820),
#  ('сколько', 818),
#  ('сходить', 817),
#  ('конец', 817),
#  ('понравиться', 816),
#  ('собираться', 815),
#  ('месяц', 813),
#  ('ваш', 811),
#  ('папа', 806),
#  ('столько', 804),
#  ('gt', 802),
#  ('умирать', 795),
#  ('девочка', 791),
#  ('стоять', 791),
#  ('мир', 789),
#  ('красивый', 786),
#  ('+', 785),
#  ('момент', 783),
#  ('далеко', 781),
#  ('бывать', 781),
#  ('вк', 777),
#  ('отвечать', 772),
#  ('елка', 770),
#  ('нога', 770),
#  ('т', 766),
#  ('поздравлять', 761),
#  ('пиздец', 761),
#  ('норма', 760),
#  ('уезжать', 758),
#  ('жалко', 756),
#  ('ибо', 751),
#  ('музыка', 745),
#  ('долго', 742),
#  ('эх', 739),
#  ('маленький', 736),
#  ('русский', 732),
#  ('экзамен', 732),
#  ('6', 730),
#  ('плакать', 728),
#  ('праздник', 728),
#  ('ребята', 727),
#  ('история', 726),
#  ('уставать', 722),
#  ('13', 721),
#  ('рад', 719),
#  ('счастие', 718),
#  ('щас', 718),
#  ('гулять', 717),
#  ('чувство', 710),
#  ('интересно', 708),
#  ('россия', 708),
#  ('учить', 706),
#  ('вспомнить', 705),
#  ('блять', 702),
#  ('немного', 701),
#  ('lt', 694),
#  ('серия', 694),
#  ('твит', 691),
#  ('казаться', 690),
#  ('душа', 688),
#  ('отличный', 688),
#  ('рассказывать', 687),
#  ('фото', 686),
#  ('старый', 686),
#  ('7', 685),
#  ('убивать', 684),
#  ('целый', 683),
#  ('приятно', 682),
#  ('игра', 680),
#  ('скучно', 679),
#  ('поехать', 679),
#  ('нормально', 670),
#  ('пить', 669),
#  ('оно', 669),
#  ('11', 669),
#  ('15', 668),
#  ('обидно', 663),
#  ('з', 663),
#  ('зато', 662),
#  ('каникулы', 662),
#  ('поставлять', 662),
#  ('лето', 655),
#  ('проблема', 649),
#  ('учиться', 648),
#  ('ой', 646),
#  ('ахахах', 646),
#  ('подруга', 645),
#  ('прекрасный', 643),
#  ('показывать', 642),
#  ('классный', 641),
#  ('ужасный', 638),
#  ('интересный', 635),
#  ('хватать', 632),
#  ('спрашивать', 630),
#  ('слишком', 627),
#  ('заболевать', 625),
#  ('ложиться', 625),
#  ('@', 623),
#  ('вместе', 623),
#  ('ага', 619),
#  ('пусть', 615),
#  ('30', 614),
#  ('сука', 611),
#  ('интернет', 610),
#  ('пол', 609),
#  ('главное', 609),
#  ('боль', 608),
#  ('группа', 603),
#  ('верить', 602),
#  ('машина', 602),
#  ('уметь', 601),
#  ('именно', 600),
#  ('0', 598),
#  ('пятница', 598),
#  ('погода', 597),
#  ('зайти', 589),
#  ('нормальный', 586),
#  ('проводить', 586),
#  ('счастливый', 581),
#  ('никак', 580),
#  ('новость', 578),
#  ('поход', 576),
#  ('ужасно', 576),
#  ('б', 576),
#  ('кот', 575),
#  ('отлично', 574),
#  ('тип', 571),
#  ('значит', 571),
#  ('москва', 569),
#  ('видео', 568),
#  ('брат', 568),
#  ('учеба', 566),
#  ('поэтому', 564),
#  ('офигенный', 561),
#  ('голос', 560),
#  ('полный', 560),
#  ('20', 560),
#  ('подумать', 559),
#  ('родитель', 559),
#  ('хах', 558),
#  ('ко', 553),
#  ('лицо', 551),
#  ('высыпаться', 550),
#  ('холодно', 550),
#  ('понедельник', 549),
#  ('тема', 548),
#  ('часто', 546),
#  ('желание', 543),
#  ('весело', 542),
#  ('назад', 540),
#  ('мысль', 537),
#  ('рядом', 537),
#  ('концерт', 536),
#  ('зачет', 536),
#  ('особенно', 535),
#  ('дорогой', 535),
#  ('магазин', 533),
#  ('нету', 533),
#  ('открывать', 531),
#  ('книга', 531),
#  ('бесить', 530),
#  ('капец', 526),
#  ('пожалуйста', 525),
#  ('сезон', 525),
#  ('петь', 525),
#  ('заниматься', 524),
#  ('план', 522),
#  ('встречать', 521),
#  ('называть', 520),
#  ('подарить', 518),
#  ('удача', 518),
#  ('боже', 517),
#  ('00', 517),
#  ('ох', 515),
#  ('замечать', 515),
#  ('сей', 507),
#  ('лишь', 506),
#  ('приятный', 503),
#  ('чай', 503),
#  ('пытаться', 502),
#  ('представлять', 498),
#  ('следующий', 498),
#  ('черт', 497),
#  ('чувак', 495),
#  ('искать', 493),
#  ('сериал', 492),
#  ('попадать', 490),
#  ('туда', 490),
#  ('обожать', 488),
#  ('заходить', 488),
#  ('готовый', 488),
#  ('прочитывать', 486),
#  ('грустно', 482),
#  ('суббота', 481),
#  ('мороз', 479),
#  ('появляться', 479),
#  ('реально', 478),
#  ('лень', 478),
#  ('никакой', 477),
#  ('жопа', 477),
#  ('сердце', 476),
#  ('происходить', 475),
#  ('нечего', 472),
#  ('кажется', 472),
#  ('ужас', 471),
#  ('сила', 470),
#  ('лежать', 469),
#  ('больно', 468),
#  ('женщина', 468),
#  ('ddd', 468),
#  ('мальчик', 463),
#  ('тви', 461),
#  ('забирать', 461),
#  ('др', 460),
#  ('ааа', 459),
#  ('встречаться', 458),
#  ('брать', 457),
#  ('общаться', 455),
#  ('потерять', 455),
#  ('прийти', 454),
#  ('сессия', 453),
#  ('уснуть', 452),
#  ('14', 452),
#  ('вернуться', 451),
#  ('окно', 451),
#  ('любой', 449),
#  ('мужик', 448),
#  ('свет', 446),
#  ('везти', 443),
#  ('декабрь', 441),
#  ('молодец', 441),
#  ('видимо', 439),
#  ('отдыхать', 435),
#  ('звонить', 435),
#  ('комп', 434),
#  ('позвонить', 433),
#  ('короче', 432),
#  ('євромайдан', 431),
#  ('обычно', 430),
#  ('всякий', 430),
#  ('аж', 430),
#  ('английский', 429),
#  ('переставать', 429),
#  ('гавно', 426),
#  ('тупой', 425),
#  ('слышать', 425),
#  ('хватить', 423),
#  ('считать', 423),
#  ('пропускать', 420),
#  ('amp', 419),
#  ('иметь', 419),
#  ('начало', 418),
#  ('вещь', 416),
#  ('соскучиться', 416),
#  ('надоедать', 415),
#  ('либо', 412),
#  ('куча', 409),
#  ('детство', 409),
#  ('сайт', 409),
#  ('страшно', 409),
#  ('печаль', 407),
#  ('переживать', 405),
#  ('снимать', 405),
#  ('мужчина', 405),
#  ('бабушка', 404),
#  ('кроме', 404),
#  ('радовать', 403),
#  ('ff', 403),
#  ('третий', 400),
#  ('желать', 400),
#  ('чо', 398),
#  ('часть', 398),
#  ('настоящий', 398),
#  ('страна', 398),
#  ('дорога', 398),
#  ('билет', 398),
#  ('поздно', 396),
#  ('еда', 396),
#  ('волос', 395),
#  ('ru', 395),
#  ('слеза', 395),
#  ('хд', 394),
#  ('придумывать', 392),
#  ('народ', 392),
#  ('заставлять', 391),
#  ('подымать', 391),
#  ('правильно', 390),
#  ('отправлять', 390),
#  ('родной', 387),
#  ('вместо', 387),
#  ('оставлять', 386),
#  ('кофе', 384),
#  ('бог', 384),
#  ('сторона', 383),
#  ('физика', 381),
#  ('общий', 381),
#  ('честно', 381),
#  ('стоить', 381),
#  ('наверно', 381),
#  ('несколько', 380),
#  ('ока', 380),
#  ('спокойный', 377),
#  ('закрывать', 377),
#  ('странный', 377),
#  ('температура', 376),
#  ('погулять', 374),
#  ('кино', 373),
#  ('смысл', 372),
#  ('сестра', 371),
#  ('подходить', 371),
#  ('удалять', 371),
#  ('ура', 370),
#  ('упасть', 369),
#  ('случаться', 367),
#  ('больница', 367),
#  ('семья', 367),
#  ('сладкий', 365),
#  ('веселый', 364),
#  ('черный', 364),
#  ('добро', 364),
#  ('обещать', 364),
#  ('квартира', 364),
#  ('картинка', 364),
#  ('похожий', 364),
#  ('отдавать', 363),
#  ('настя', 362),
#  ('случай', 362),
#  ('каток', 361),
#  ('страшный', 360),
#  ('просить', 359),
#  ('выбирать', 357),
#  ('доставать', 357),
#  ('вид', 356),
#  ('супер', 356),
#  ('сначала', 354),
#  ('99', 353),
#  ('постоянно', 353),
#  ('бедный', 352),
#  ('ставить', 351),
#  ('готовить', 350),
#  ('январь', 350),
#  ('ответ', 349),
#  ('радость', 349),
#  ('готовиться', 347),
#  ('единственный', 346),
#  ('сниться', 345),
#  ('автобус', 344),
#  ('знакомый', 343),
#  ('химия', 343),
#  ('даа', 342),
#  ('танец', 342),
#  ('поговорить', 342),
#  ('включать', 341),
#  ('лох', 341),
#  ('звать', 341),
#  ('мечта', 340),
#  ('разный', 339),
#  ('ощущение', 338),
#  ('огромный', 338),
#  ('собака', 337),
#  ('номер', 335),
#  ('белый', 334),
#  ('комната', 334),
#  ('похоже', 334),
#  ('письмо', 333),
#  ('вода', 332),
#  ('вспоминать', 332),
#  ('действительно', 332),
#  ('напоминать', 331),
#  ('собирать', 331),
#  ('поспать', 330),
#  ('бегать', 330),
#  ('садиться', 330),
#  ('ум', 328),
#  ('имя', 327),
#  ('фигня', 326),
#  ('выздоравливать', 326),
#  ('аааа', 325),
#  ('кушать', 324),
#  ('покупать', 324),
#  ('предлагать', 323),
#  ('рабочий', 322),
#  ('страница', 322),
#  ('улыбаться', 321),
#  ('попробовать', 321),
#  ('наступать', 319),
#  ('сообщение', 319),
#  ('жена', 319),
#  ('саша', 319),
#  ('дождь', 319),
#  ('кинуть', 318),
#  ('идиот', 318),
#  ('нос', 316),
#  ('бросать', 315),
#  ('лола', 314),
#  ('половина', 314),
#  ('тренировка', 312),
#  ('обязательно', 311),
#  ('тепло', 309),
#  ('обижаться', 309),
#  ('гость', 308),
#  ('мозг', 307),
#  ('обратно', 307),
#  ('испортить', 306),
#  ('шок', 305),
#  ('дура', 305),
#  ('100', 305),
#  ('ооо', 305),
#  ('вернуть', 304),
#  ('одноклассник', 304),
#  ('принимать', 303),
#  ('отмечать', 302),
#  ('фотография', 302),
#  ('итог', 301),
#  ('ебать', 301),
#  ('муж', 300),
#  ('язык', 300),
#  ('сожаление', 299),
#  ('жрать', 299),
#  ('горло', 299),
#  ('везде', 298),
#  ('помощь', 298),
#  ('съедать', 298),
#  ('украина', 297),
#  ('зря', 297),
#  ('легко', 297),
#  ('устраивать', 295),
#  ('доходить', 293),
#  ('смеяться', 292),
#  ('ездить', 292),
#  ('настолько', 292),
#  ('разговаривать', 291),
#  ('майдан', 290),
#  ('смешно', 290),
#  ('загадывать', 290),
#  ('воскресение', 290),
#  ('безумно', 290),
#  ('контрольный', 289),
#  ('красный', 289),
#  ('скидывать', 288),
#  ('отпускать', 287),
#  ('универ', 287),
#  ('состояние', 287),
#  ('кровать', 287),
#  ('приносить', 287),
#  ('прямо', 287),
#  ('вкусный', 287),
#  ('классно', 286),
#  ('пропадать', 286),
#  ('л', 284),
#  ('против', 284),
#  ('забивать', 283),
#  ('идея', 283),
#  ('некоторый', 282),
#  ('алгебра', 281),
#  ('встреча', 280),
#  ('молодежка', 280),
#  ('стол', 280),
#  ('привыкать', 279),
#  ('ржать', 279),
#  ('добавлять', 278),
#  ('ради', 278),
#  ('р', 277),
#  ('пробка', 276),
#  ('кончаться', 276),
#  ('просыпать', 275),
#  ('близкий', 275),
#  ('понятно', 275),
#  ('печально', 274),
#  ('живой', 274),
#  ('радоваться', 274),
#  ('число', 274),
#  ('сегодняшний', 273),
#  ('важный', 273),
#  ('шикарный', 272),
#  ('палец', 272),
#  ('опаздывать', 271),
#  ('контакт', 270),
#  ('дааа', 269),
#  ('баба', 269),
#  ('ах', 269),
#  ('катя', 269),
#  ('платье', 268),
#  ('видно', 268),
#  ('вести', 268),
#  ('прошлый', 267),
#  ('шк', 267),
#  ('хуй', 267),
#  ('д', 267),
#  ('оч', 267),
#  ('очередной', 266),
#  ('никуда', 264),
#  ('обнимать', 264),
#  ('выпивать', 263),
#  ('повод', 263),
#  ('путин', 263),
#  ('называться', 263),
#  ('чудо', 263),
#  ('танцевать', 262),
#  ('грустный', 262),
#  ('недавно', 262),
#  ('нахуй', 261),
#  ('читатель', 261),
#  ('вокруг', 260),
#  ('выглядеть', 260),
#  ('главный', 259),
#  ('дождаться', 259),
#  ('16', 259),
#  ('ток', 259),
#  ('шутка', 258),
#  ('метро', 257),
#  ('попросить', 256),
#  ('е', 256),
#  ('сложно', 256),
#  ('красиво', 255),
#  ('пост', 255),
#  ('стыдно', 255),
#  ('например', 254),
#  ('пять', 254),
#  ('дед', 253),
#  ('поддерживать', 253),
#  ('сломать', 253),
#  ('продолжать', 252),
#  ('злой', 252),
#  ('фу', 252),
#  ('оценка', 252),
#  ('спасать', 252),
#  ('бл', 252),
#  ('рисовать', 251),
#  ('хрен', 250),
#  ('вчерашний', 250),
#  ('заказывать', 250),
#  ('учитель', 250),
#  ('согласный', 250),
#  ('сосед', 249),
#  ('ухо', 249),
#  ('странно', 249),
#  ('простой', 249),
#  ('оо', 249),
#  ('увы', 248),
#  ('киев', 248),
#  ('заканчивать', 248),
#  ('задавать', 248),
#  ('питер', 248),
#  ('убирать', 247),
#  ('тяжелый', 246),
#  ('господи', 246),
#  ('мать', 246),
#  ('кой', 245),
#  ('ошибка', 244),
#  ('q', 244),
#  ('пацан', 244),
#  ('18', 244),
#  ('теплый', 243),
#  ('разговор', 243),
#  ('p', 243),
#  ('расстраиваться', 243),
#  ('замечательный', 243),
#  ('замерзать', 242),
#  ('держать', 242),
#  ('волгоград', 242),
#  ('сложный', 242),
#  ('ппц', 242),
#  ('тяжело', 241),
#  ('кататься', 241),
#  ('цвет', 240),
#  ('хуйня', 240),
#  ('компания', 239),
#  ('пздц', 239),
#  ('мечтать', 239),
#  ('курс', 238),
#  ('статус', 238),
#  ('отношение', 238),
#  ('выучивать', 237),
#  ('айфон', 237),
#  ('шапка', 237),
#  ('ожидать', 237),
#  ('олимпиада', 236),
#  ('вариант', 235),
#  ('поверять', 235),
#  ('сюда', 234),
#  ('follow', 234),
#  ('врач', 233),
#  ('продавать', 233),
#  ('50', 233),
#  ('рубль', 233),
#  ('инет', 233),
#  ('жесть', 232),
#  ('умный', 232),
#  ('правый', 231),
#  ('кровь', 231),
#  ('снежок', 231),
#  ('уверенный', 230),
#  ('пускать', 229),
#  ('присниться', 229),
#  ('список', 229),
#  ('пиво', 228),
#  ('близко', 228),
#  ('стараться', 228),
#  ('сутки', 228),
#  ('смешной', 228),
#  ('жуйк', 227),
#  ('го', 227),
#  ('находиться', 227),
#  ('вечно', 226),
#  ('виноватый', 226),
#  ('реклама', 225),
#  ('ситуация', 225),
#  ('память', 224),
#  ('курить', 224),
#  ('красота', 224),
#  ('возможно', 223),
#  ('40', 223),
#  ('ааааа', 223),
#  ('футбол', 223),
#  ('создавать', 223),
#  ('команда', 222),
#  ('остальной', 222),
#  ('срочно', 222),
#  ('извинять', 221),
#  ('сеть', 221),
#  ('неужели', 221),
#  ('н', 221),
#  ('удаваться', 220),
#  ('альбом', 220),
#  ('шо', 220),
#  ('право', 219),
#  ('ноут', 218),
#  ('орать', 218),
#  ('завидовать', 218),
#  ('збс', 218),
#  ('ретвлять', 217),
#  ('штука', 217),
#  ('хз', 217),
#  ('обновлять', 216),
#  ('центр', 216),
#  ('аня', 216),
#  ('поиграть', 216),
#  ('фраза', 215),
#  ('весна', 215),
#  ('http', 215),
#  ('спокойно', 215),
#  ('кошка', 215),
#  ('отказываться', 215),
#  ('серьезно', 215),
#  ('м', 214),
#  ('ща', 214),
#  ('откуда', 214),
#  ('проверять', 214),
#  ('здоровье', 214),
#  ('даша', 213),
#  ('ха', 213),
#  ('послушать', 213),
#  ('почитать', 213),
#  ('занимать', 213),
#  ('нь', 213),
#  ('дима', 213),
#  ('улыбка', 212),
#  ('свободный', 212),
#  ('математика', 212),
#  ('здорово', 212),
#  ('сильный', 212),
#  ('редко', 212),
#  ('очередь', 212),
#  ('впервые', 212),
#  ('причем', 211),
#  ('клуб', 210),
#  ('спина', 210),
#  ('геометрия', 209),
#  ('живот', 209),
#  ('зимний', 209),
#  ('2014', 209),
#  ('иначе', 209),
#  ('оба', 209),
#  ('держаться', 208),
#  ('сбываться', 207),
#  ('посылать', 207),
#  ('посидеть', 206),
#  ('2013', 206),
#  ('высокий', 205),
#  ('ссылка', 205),
#  ('дарить', 205),
#  ('тож', 205),
#  ('набирать', 205),
#  ('влюбляться', 205),
#  ('выигрывать', 204),
#  ('обычный', 204),
#  ('почта', 204),
#  ('пипец', 203),
#  ('трудно', 203),
#  ('идеальный', 202),
#  ('пизда', 202),
#  ('одевать', 202),
#  ('шерлок', 202),
#  ('личный', 201),
#  ('четверг', 201),
#  ('возможность', 201),
#  ('карта', 201),
#  ('зуб', 200),
#  ('подряд', 200),
#  ('результат', 200),
#  ('исправлять', 199),
#  ('случайно', 199),
#  ('выкладывать', 199),
#  ('мнение', 199),
#  ('передавать', 199),
#  ('позитив', 199),
#  ('тупо', 198),
#  ('биология', 198),
#  ('тело', 198),
#  ('счет', 197),
#  ('название', 197),
#  ('кароч', 196),
#  ('солнце', 196),
#  ('разбивать', 196),
#  ('около', 196),
#  ('ска', 196),
#  ('эмоция', 195),
#  ('менять', 195),
#  ('игрушка', 195),
#  ('зал', 194),
#  ('17', 194),
#  ('причина', 194),
#  ('судьба', 194),
#  ('захотеть', 193),
#  ('маша', 193),
#  ('клевый', 193),
#  ('горячий', 193),
#  ('херня', 193),
#  ('огонь', 193),
#  ('молчать', 193),
#  ('звезда', 192),
#  ('малый', 192),
#  ('хреновый', 192),
#  ('беда', 192),
#  ('программа', 192),
#  ('заебывать', 192),
#  ('вика', 191),
#  ('teamfollowback', 191),
#  ('ти', 191),
#  ('детский', 191),
#  ('ого', 190),
#  ('разбираться', 189),
#  ('внимание', 189),
#  ('секс', 189),
#  ('блиин', 188),
#  ('хахах', 188),
#  ('удачный', 188),
#  ('плюс', 187),
#  ('услышать', 187),
#  ('значить', 187),
#  ('ад', 187),
#  ('стена', 187),
#  ('полагать', 186),
#  ('шоколадка', 186),
#  ('страдать', 186),
#  ('конфета', 186),
#  ('падать', 186),
#  ('25', 185),
#  ('мило', 185),
#  ('21', 185),
#  ('скачать', 185),
#  ('обед', 185),
#  ('хрень', 184),
#  ('украшать', 184),
#  ('скайп', 184),
#  ('пьяный', 184),
#  ('платить', 184),
#  ('поесть', 183),
#  ('привозить', 183),
#  ('бежать', 183),
#  ('расстраивать', 183),
#  ('победитель', 183),
#  ('великий', 182),
#  ('мелкий', 182),
#  ('вкус', 182),
#  ('объяснять', 182),
#  ('ч', 182),
#  ('серый', 181),
#  ('жизньболь', 181),
#  ('полностью', 181),
#  ('инстаграм', 181),
#  ('должно', 181),
#  ('вызывать', 181),
#  ('российский', 181),
#  ('путь', 180),
#  ('особо', 180),
#  ('33', 180),
#  ('слава', 180),
#  ('пароль', 180),
#  ('увидеться', 180),
#  ('разбудить', 180),
#  ('п', 180),
#  ('факт', 180),
#  ('кошмар', 179),
#  ('бывший', 179),
#  ('малыш', 179),
#  ('минус', 179),
#  ('пересматривать', 179),
#  ('мандарин', 179),
#  ('кидать', 179),
#  ('море', 179),
#  ('наушники', 178),
#  ('ка', 178),
#  ('чета', 178),
#  ...]

# %%
pd.Series(word_counts).describe(percentiles=[0.75, 0.9, 0.95, 0.99])
# Out:
# count     89395.000000
# mean         20.415907
# std         941.129933
# min           1.000000
# 50%           1.000000
# 75%           3.000000
# 90%          11.000000
# 95%          29.000000
# 99%         200.000000
# max      159350.000000
# dtype: float64

# %% [markdown]
# Видно, что уникальных токенов стало меньше, чаще всего встречается пунктуация, ссылки и необработанные стоп-слова. Возьмём топ-25% слов

# %%
max_words = int(len(word_counts) * 0.25)

# %%
X_train_transformed = transform(X_train_processed, word_counts, max_words, max_twords)

# %%
embedding_dim = 32
model = Sequential([
    Embedding(max_words + 2, embedding_dim, mask_zero=True, embeddings_initializer=RandomUniform(-0.01, 0.01, seed=42)),
    LSTM(128, kernel_initializer=glorot_uniform(seed=42), dropout=0.1, recurrent_dropout=0.1),
    Dense(1, activation='tanh')
])

# %%
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=[roc_auc])

# %%
model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_4 (Embedding)      (None, None, 32)          715200
# _________________________________________________________________
# lstm_4 (LSTM)                (None, 128)               82432
# _________________________________________________________________
# dense_4 (Dense)              (None, 1)                 129
# =================================================================
# Total params: 797,761
# Trainable params: 797,761
# Non-trainable params: 0
# _________________________________________________________________

# %%
batch_size = 2000
max_epochs = 10
model.fit(X_train_transformed, y_train, epochs=max_epochs, batch_size=batch_size, shuffle=True, verbose=1)
# Out:
# /home/nikolai/Projects/MIPT-ML-Fall-2019/env/lib/python3.7/site-packages/tensorflow_core/python/framework/indexed_slices.py:424: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# Epoch 1/10
# 170125/170125 [==============================] - 205s 1ms/step - loss: -4.3384 - roc_auc: 0.9826
# Epoch 2/10
# 170125/170125 [==============================] - 200s 1ms/step - loss: -6.2912 - roc_auc: 0.9921
# Epoch 3/10
# 170125/170125 [==============================] - 200s 1ms/step - loss: -6.3722 - roc_auc: 0.9929
# Epoch 4/10
# 170125/170125 [==============================] - 200s 1ms/step - loss: -6.9156 - roc_auc: 0.9970
# Epoch 5/10
# 170125/170125 [==============================] - 199s 1ms/step - loss: -7.1132 - roc_auc: 0.9976
# Epoch 6/10
# 170125/170125 [==============================] - 199s 1ms/step - loss: -7.2124 - roc_auc: 0.9981
# Epoch 7/10
# 170125/170125 [==============================] - 199s 1ms/step - loss: -7.2672 - roc_auc: 0.9987
# Epoch 8/10
# 170125/170125 [==============================] - 200s 1ms/step - loss: -7.2772 - roc_auc: 0.9988
# Epoch 9/10
# 170125/170125 [==============================] - 200s 1ms/step - loss: -7.2004 - roc_auc: 0.9983
# Epoch 10/10
# 170125/170125 [==============================] - 200s 1ms/step - loss: -7.3222 - roc_auc: 0.9990

# %%
# %%time
X_test_processed = X_test.apply(process)
X_test_processed = X_test_processed.str.split(' ').apply(lambda x: ' '.join(y for y in x if y not in stop_words))
X_test_transformed = transform(X_test_processed, word_counts, max_words, max_twords)
# Out:
# CPU times: user 8.84 s, sys: 911 ms, total: 9.75 s
# Wall time: 39.5 s

# %%
model.evaluate(X_test_transformed, y_test)
# Out:
# 56709/56709 [==============================] - 41s 727us/step
# [-7.010739052562024, 0.9941747784614563]
